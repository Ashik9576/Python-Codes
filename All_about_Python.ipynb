# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashik9576/Python-Codes/blob/main/All_about_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python_All_Concepts**

# %% [markdown]
# # **Pandas**

# %%
# mounting drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#importing pandas
import pandas as pd

#reading csv file
df=pd.read_csv('/content/drive/My Drive/COVID-19 Coronavirus.csv')

# reading excel file
# df=pd.read_excel()
# pd.read_(file_type)(file_name)

# %%
df.head()
# Out:
#        Country  Other names ISO 3166-1 alpha-3 CODE  Population Continent  \
# 0  Afghanistan  Afghanistan                     AFG    40462186      Asia
# 1      Albania      Albania                     ALB     2872296    Europe
# 2      Algeria      Algeria                     DZA    45236699    Africa
# 3      Andorra      Andorra                     AND       77481    Europe
# 4       Angola       Angola                     AGO    34654212    Africa
#
#    Total Cases  Total Deaths  Tot Cases//1M pop  Tot Deaths/1M pop  \
# 0       177827          7671               4395                190
# 1       273870          3492              95349               1216
# 2       265691          6874               5873                152
# 3        40024           153             516565               1975
# 4        99194          1900               2862                 55
#
#    Death percentage
# 0          4.313743
# 1          1.275058
# 2          2.587216
# 3          0.382271
# 4          1.915438

# %%
#writing csv file
#df=pd.to_csv('/content/drive/My Drive/COVID-19 Coronavirus.csv')

# writing excel file
# df=pd.to_excel()
# pd.to_(file_type)(file_name)

# %%
# selecting a column
df['Country']
# Out:
# 0            Afghanistan
# 1                Albania
# 2                Algeria
# 3                Andorra
# 4                 Angola
#              ...
# 220    Wallis and Futuna
# 221       Western Sahara
# 222                Yemen
# 223               Zambia
# 224             Zimbabwe
# Name: Country, Length: 225, dtype: object

# %%
# selecting multiple columns
df[['Country','Population','Continent']]
# Out:
#                Country  Population Continent
# 0          Afghanistan    40462186      Asia
# 1              Albania     2872296    Europe
# 2              Algeria    45236699    Africa
# 3              Andorra       77481    Europe
# 4               Angola    34654212    Africa
# ..                 ...         ...       ...
# 220  Wallis and Futuna       10894   Oceania
# 221     Western Sahara      623031    Africa
# 222              Yemen    30975258      Asia
# 223             Zambia    19284482    Africa
# 224           Zimbabwe    15241601    Africa
#
# [225 rows x 3 columns]

# %%
# selecting rows by index
df.iloc[:6]
# Out:
#        Country  Other names ISO 3166-1 alpha-3 CODE  Population  \
# 0  Afghanistan  Afghanistan                     AFG    40462186
# 1      Albania      Albania                     ALB     2872296
# 2      Algeria      Algeria                     DZA    45236699
# 3      Andorra      Andorra                     AND       77481
# 4       Angola       Angola                     AGO    34654212
# 5     Anguilla     Anguilla                     AIA       15237
#
#                          Continent  Total Cases  Total Deaths  \
# 0                             Asia       177827          7671
# 1                           Europe       273870          3492
# 2                           Africa       265691          6874
# 3                           Europe        40024           153
# 4                           Africa        99194          1900
# 5  Latin America and the Caribbean         2700             9
#
#    Tot Cases//1M pop  Tot Deaths/1M pop  Death percentage
# 0               4395                190          4.313743
# 1              95349               1216          1.275058
# 2               5873                152          2.587216
# 3             516565               1975          0.382271
# 4               2862                 55          1.915438
# 5             177200                591          0.333333

# %%
df.iloc[:6:2]
# Out:
#        Country  Other names ISO 3166-1 alpha-3 CODE  Population Continent  \
# 0  Afghanistan  Afghanistan                     AFG    40462186      Asia
# 2      Algeria      Algeria                     DZA    45236699    Africa
# 4       Angola       Angola                     AGO    34654212    Africa
#
#    Total Cases  Total Deaths  Tot Cases//1M pop  Tot Deaths/1M pop  \
# 0       177827          7671               4395                190
# 2       265691          6874               5873                152
# 4        99194          1900               2862                 55
#
#    Death percentage
# 0          4.313743
# 2          2.587216
# 4          1.915438

# %%
# selecting column by position
df.iloc[:5,:3]
# Out:
#        Country  Other names ISO 3166-1 alpha-3 CODE
# 0  Afghanistan  Afghanistan                     AFG
# 1      Albania      Albania                     ALB
# 2      Algeria      Algeria                     DZA
# 3      Andorra      Andorra                     AND
# 4       Angola       Angola                     AGO

# %%
df[df['Death percentage']>2]
# Out:
#                     Country                                Other names  \
# 0               Afghanistan                                Afghanistan
# 2                   Algeria                                    Algeria
# 8                   Armenia                                    Armenia
# 13                  Bahamas                                    Bahamas
# 23                  Bolivia           Bolivia (Plurinational State of)
# 24   Bosnia and Herzegovina                     Bosnia and Herzegovina
# 26                   Brazil                                     Brazil
# 29                 Bulgaria                                   Bulgaria
# 33                 Cambodia                                   Cambodia
# 39                     Chad                                       Chad
# 42                    China                                      China
# 43                 Colombia                                   Colombia
# 58                  Ecuador                                    Ecuador
# 59                    Egypt                                      Egypt
# 60              El Salvador                                El Salvador
# 74                   Gambia                                     Gambia
# 83                Guatemala                                  Guatemala
# 85            Guinea-Bissau                              Guinea-Bissau
# 87                    Haiti                                      Haiti
# 88                 Honduras                                   Honduras
# 90                  Hungary                                    Hungary
# 93                Indonesia                                  Indonesia
# 101                 Jamaica                                    Jamaica
# 112                 Lesotho                                    Lesotho
# 113                 Liberia                                    Liberia
# 119              Madagascar                                 Madagascar
# 120                  Malawi                                     Malawi
# 123                    Mali                                       Mali
# 128               Mauritius                                  Mauritius
# 130                  Mexico                                     Mexico
# 132                 Moldova                        Republic of Moldova
# 139                 Myanmar                                    Myanmar
# 140                 Namibia                                    Namibia
# 146                   Niger                                      Niger
# 149         North Macedonia  The former Yugoslav Republic of Macedonia
# 157                Paraguay                                   Paraguay
# 158                    Peru                                       Peru
# 164                 Romania                                    Romania
# 165                  Russia                         Russian Federation
# 177                 Senegal                                    Senegal
# 186                 Somalia                                    Somalia
# 187            South Africa                               South Africa
# 190               Sri Lanka                                  Sri Lanka
# 193                   Sudan                                      Sudan
# 197                   Syria                       Syrian Arab Republic
# 198                  Taiwan            China, Taiwan Province of China
# 200                Tanzania                United Republic of Tanzania
# 205     Trinidad and Tobago                        Trinidad and Tobago
# 206                 Tunisia                                    Tunisia
# 210                  Uganda                                     Uganda
# 212                 Ukraine                                    Ukraine
# 221          Western Sahara                             Western Sahara
# 222                   Yemen                                      Yemen
# 224                Zimbabwe                                   Zimbabwe
#
#     ISO 3166-1 alpha-3 CODE  Population                        Continent  \
# 0                       AFG    40462186                             Asia
# 2                       DZA    45236699                           Africa
# 8                       ARM     2972939                             Asia
# 13                      BHM      399822  Latin America and the Caribbean
# 23                      BOL    11951714  Latin America and the Caribbean
# 24                      BIH     3245097                           Europe
# 26                      BRA   215204501  Latin America and the Caribbean
# 29                      BGR     6856886                           Europe
# 33                      KHM    17123941                             Asia
# 39                      TCD    17250246                           Africa
# 42                      CHN  1439323776                             Asia
# 43                      COL    51832231  Latin America and the Caribbean
# 58                      ECU    18111933  Latin America and the Caribbean
# 59                      EGY   105711844                           Africa
# 60                      SLV     6543499  Latin America and the Caribbean
# 74                      GMB     2535418                           Africa
# 83                      GTM    18495493  Latin America and the Caribbean
# 85                      GNB     2049374                           Africa
# 87                      HTI    11645833  Latin America and the Caribbean
# 88                      HND    10180299  Latin America and the Caribbean
# 90                      HUN     9617409                           Europe
# 93                      IDN   278586508                             Asia
# 101                     JAM     2983794  Latin America and the Caribbean
# 112                     LSO     2171978                           Africa
# 113                     LBR     5265647                           Africa
# 119                     MDG    28936285                           Africa
# 120                     MWI    19994654                           Africa
# 123                     MLI    21271006                           Africa
# 128                     MUS     1275463                           Africa
# 130                     MEX   131303955  Latin America and the Caribbean
# 132                     MDA     4017550                           Europe
# 139                     MMR    55048340                             Asia
# 140                     NAM     2621429                           Africa
# 146                     NER    25738714                           Africa
# 149                     MKD     2083224                           Europe
# 157                     PRY     7285892  Latin America and the Caribbean
# 158                     PER    33775745  Latin America and the Caribbean
# 164                     ROU    19013049                           Europe
# 165                     RUS   146044010                           Europe
# 177                     SEN    17515750                           Africa
# 186                     SOM    16668781                           Africa
# 187                     ZAF    60617532                           Africa
# 190                     LKA    21570428                             Asia
# 193                     SDN    45640385                           Africa
# 197                     SYR    18244381                             Asia
# 198                     TWN    23892241                             Asia
# 200                     TZA    62710097                           Africa
# 205                     TTO     1407422  Latin America and the Caribbean
# 206                     TUN    12035092                           Africa
# 210                     UGA    48267221                           Africa
# 212                     UKR    43273831                           Europe
# 221                   ESHÂ       623031                           Africa
# 222                     YEM    30975258                             Asia
# 224                     ZWE    15241601                           Africa
#
#      Total Cases  Total Deaths  Tot Cases//1M pop  Tot Deaths/1M pop  \
# 0         177827          7671               4395                190
# 2         265691          6874               5873                152
# 8         422574          8617             142140               2898
# 13         33295           788              83275               1971
# 23        902448         21896              75508               1832
# 24        375693         15719             115773               4844
# 26      29999816        660269             139401               3068
# 29       1140679         36568             166355               5333
# 33        135747          3054               7927                178
# 39          7308           191                424                 11
# 42        154738          4638                108                  3
# 43       6085926        139660             117416               2694
# 58        859890         35421              47476               1956
# 59        505264         24417               4780                231
# 60        161570          4120              24692                630
# 74         11988           365               4728                144
# 83        830745         17325              44916                937
# 85          8151           170               3977                 83
# 87         30549           833               2623                 72
# 88        421062         10880              41360               1069
# 90       1854198         45510             192796               4732
# 93       6019981        155288              21609                557
# 101       128811          2893              43170                970
# 112        32910           697              15152                321
# 113         7400           294               1405                 56
# 119        64050          1388               2213                 48
# 120        85664          2626               4284                131
# 123        30495           728               1434                 34
# 128        36628           968              28717                759
# 130      5665376        323212              43147               2462
# 132       514199         11446             127988               2849
# 139       611875         19433              11115                353
# 140       157646          4019              60137               1533
# 146         8811           308                342                 12
# 149       306670          9228             147209               4430
# 157       648353         18731              88987               2571
# 158      3548559        212328             105062               6286
# 164      2860094         65090             150428               3423
# 165     17896866        369708             122544               2531
# 177        85919          1965               4905                112
# 186        26400          1348               1584                 81
# 187      3722954        100050              61417               1651
# 190       661991         16481              30690                764
# 193        61955          4907               1357                108
# 197        55711          3144               3054                172
# 198        24310           853               1017                 36
# 200        33815           800                539                 13
# 205       138425          3756              98354               2669
# 206      1035884         28323              86072               2353
# 210       163936          3595               3396                 74
# 212      4968881        107980             114824               2495
# 221           10             1                 16                  2
# 222        11806          2143                381                 69
# 224       246525          5446              16174                357
#
#      Death percentage
# 0            4.313743
# 2            2.587216
# 8            2.039169
# 13           2.366722
# 23           2.426289
# 24           4.184001
# 26           2.200910
# 29           3.205810
# 33           2.249773
# 39           2.613574
# 42           2.997325
# 43           2.294803
# 58           4.119248
# 59           4.832523
# 60           2.549978
# 74           3.044711
# 83           2.085477
# 85           2.085634
# 87           2.726767
# 88           2.583943
# 90           2.454430
# 93           2.579543
# 101          2.245926
# 112          2.117897
# 113          3.972973
# 119          2.167057
# 120          3.065465
# 123          2.387277
# 128          2.642787
# 130          5.705041
# 132          2.225986
# 139          3.175975
# 140          2.549383
# 146          3.495630
# 149          3.009098
# 157          2.889013
# 158          5.983499
# 164          2.275799
# 165          2.065770
# 177          2.287038
# 186          5.106061
# 187          2.687382
# 190          2.489611
# 193          7.920265
# 197          5.643410
# 198          3.508844
# 200          2.365814
# 205          2.713383
# 206          2.734186
# 210          2.192929
# 212          2.173125
# 221         10.000000
# 222         18.151787
# 224          2.209107

# %%
#Create dataframe
data = {'name': ['Kunal', 'Ankit', 'Purva', 'Pranav', 'Sunil'], 
        'age': [42, 52, 36, 24, 73], 
        'TestScore_1': [4, 24, 31, 2, 3],
        'TestScore_2': [25, 94, 57, 62, 70]}
df = pd.DataFrame(data, columns = ['name', 'age', 'TestScore_1', 'TestScore_2'])
df
# Out:
#      name  age  TestScore_1  TestScore_2
# 0   Kunal   42            4           25
# 1   Ankit   52           24           94
# 2   Purva   36           31           57
# 3  Pranav   24            2           62
# 4   Sunil   73            3           70

# %%
#sum of all ages
df['age'].sum()
# Out:
# 227

# %%
#mean of testscore1
df['TestScore_1'].mean()
# Out:
# 12.8

# %%
#Cumulative sum of TestScore_1s, moving from the rows from the top
df['TestScore_1'].cumsum()
# Out:
# 0     4
# 1    28
# 2    59
# 3    61
# 4    64
# Name: TestScore_1, dtype: int64

# %%
#Summary statistics on TestScore_1
df['TestScore_1'].describe()
# Out:
# count     5.000000
# mean     12.800000
# std      13.663821
# min       2.000000
# 25%       3.000000
# 50%       4.000000
# 75%      24.000000
# max      31.000000
# Name: TestScore_1, dtype: float64

# %%
#Count the number of non-NA values
df['TestScore_1'].count()
# Out:
# 5

# %%
#Minimum value of TestScore_1
df['TestScore_1'].min()
# Out:
# 2

# %%
#Maximum value of TestScore_1
df['TestScore_1'].max()
# Out:
# 31

# %%
#Median value of TestScore_1
df['TestScore_1'].median()
# Out:
# 4.0

# %%
#Sample variance of TestScore_1 values
df['TestScore_1'].var()
# Out:
# 186.7

# %%
#Sample standard deviation of TestScore_1 values
df['TestScore_1'].std()
# Out:
# 13.663820841916802

# %%
#Skewness of preTestScore values
df['TestScore_1'].skew()
# Out:
# 0.7433452457326751

# %%
#Kurtosis of TestScore_1 values
df['TestScore_1'].kurt()
# Out:
# -2.4673543738411547

# %%
#Correlation Matrix Of Values
df.corr()
# Out:
#                   age  TestScore_1  TestScore_2
# age          1.000000    -0.105651     0.328852
# TestScore_1 -0.105651     1.000000     0.378039
# TestScore_2  0.328852     0.378039     1.000000

# %%
#Covariance Matrix Of Values
df.cov()
# Out:
#                 age  TestScore_1  TestScore_2
# age          340.80       -26.65       151.20
# TestScore_1  -26.65       186.70       128.65
# TestScore_2  151.20       128.65       620.30

# %%
#Plotting (Boxplot & Histogram) with Pandas

df.boxplot(column="TestScore_1",by="TestScore_2")

# %%
# Rename the column name
df.columns = ['a','b','c','d']
df
# Out:
#         a   b   c   d
# 0   Kunal  42   4  25
# 1   Ankit  52  24  94
# 2   Purva  36  31  57
# 3  Pranav  24   2  62
# 4   Sunil  73   3  70

# %%
#The other technique for renaming column labels is to call the rename method on the DataFrame object, then passing our list of label values to the columns parameter:

df = pd.DataFrame([('The Hobbit','J.R.R. Tolkien'),
    ('Robinson Crusoe','Daniel Defoe'),
    ('Moby-Dick','Herman Melville')])

# %%
df
# Out:
#                  0                1
# 0       The Hobbit   J.R.R. Tolkien
# 1  Robinson Crusoe     Daniel Defoe
# 2        Moby-Dick  Herman Melville

# %%
# renaming the columns
df.rename(columns={0 : 'title',1 : 'author'},inplace=True)

# %%
df
# Out:
#              title           author
# 0       The Hobbit   J.R.R. Tolkien
# 1  Robinson Crusoe     Daniel Defoe
# 2        Moby-Dick  Herman Melville

# %%
#Create dataframe
data = {'name': ['Kunal', 'Ankit', 'Purva', 'Pranav', 'Sunil'], 
        'age': [42, 52, 36, 24, 73], 
        'TestScore_1': [4, 24, 31, 2, 3],
        'TestScore_2': [25, 94, 57, 62, 70]}
df = pd.DataFrame(data, columns = ['name', 'age', 'TestScore_1', 'TestScore_2'])
df
# Out:
#      name  age  TestScore_1  TestScore_2
# 0   Kunal   42            4           25
# 1   Ankit   52           24           94
# 2   Purva   36           31           57
# 3  Pranav   24            2           62
# 4   Sunil   73            3           70

# %%
# sorting the dataset by one columns
sorted_df=df.sort_values(by='TestScore_1')
sorted_df
# Out:
#      name  age  TestScore_1  TestScore_2
# 3  Pranav   24            2           62
# 4   Sunil   73            3           70
# 0   Kunal   42            4           25
# 1   Ankit   52           24           94
# 2   Purva   36           31           57

# %%
df
# Out:
#      name  age  TestScore_1  TestScore_2
# 0   Kunal   42            4           25
# 1   Ankit   52           24           94
# 2   Purva   36           31           57
# 3  Pranav   24            2           62
# 4   Sunil   73            3           70

# %%
# sorting of dataframe permanentally
df.sort_values(by='TestScore_1', ascending=False, inplace=True)

# %%
df
# Out:
#      name  age  TestScore_1  TestScore_2
# 2   Purva   36           31           57
# 1   Ankit   52           24           94
# 0   Kunal   42            4           25
# 4   Sunil   73            3           70
# 3  Pranav   24            2           62

# %%
#sorting the dataframe with multiple column
df.sort_values(by=['TestScore_1','TestScore_2'], ascending=True, inplace=True)

# %%
df
# Out:
#      name  age  TestScore_1  TestScore_2
# 3  Pranav   24            2           62
# 4   Sunil   73            3           70
# 0   Kunal   42            4           25
# 1   Ankit   52           24           94
# 2   Purva   36           31           57

# %%
#sort by index
df.sort_index(inplace=True)

# %%
df
# Out:
#      name  age  TestScore_1  TestScore_2
# 0   Kunal   42            4           25
# 1   Ankit   52           24           94
# 2   Purva   36           31           57
# 3  Pranav   24            2           62
# 4   Sunil   73            3           70

# %%
import numpy as np
df_ages = pd.DataFrame({'age': np.random.randint(21, 51, 8)})

# %%
df_ages
# Out:
#    age
# 0   29
# 1   25
# 2   33
# 3   30
# 4   49
# 5   36
# 6   21
# 7   22

# %%
df_ages['age_bins'] = pd.cut(x=df_ages['age'], bins=[20, 29, 39, 49])

# %%
df_ages
# Out:
#    age  age_bins
# 0   29  (20, 29]
# 1   25  (20, 29]
# 2   33  (29, 39]
# 3   30  (29, 39]
# 4   49  (39, 49]
# 5   36  (29, 39]
# 6   21  (20, 29]
# 7   22  (20, 29]

# %%
df_ages['age_by_decade'] = pd.cut(x=df_ages['age'], bins=[20, 29, 39, 49], labels=['20s', '30s', '40s'])

# %%
df_ages
# Out:
#    age  age_bins age_by_decade
# 0   29  (20, 29]           20s
# 1   25  (20, 29]           20s
# 2   33  (29, 39]           30s
# 3   30  (29, 39]           30s
# 4   49  (39, 49]           40s
# 5   36  (29, 39]           30s
# 6   21  (20, 29]           20s
# 7   22  (20, 29]           20s

# %%
df
# Out:
#      name  age  TestScore_1  TestScore_2
# 0   Kunal   42            4           25
# 1   Ankit   52           24           94
# 2   Purva   36           31           57
# 3  Pranav   24            2           62
# 4   Sunil   73            3           70

# %%
from scipy.stats import mode
mode(df['age'])
# Out:
# ModeResult(mode=array([24]), count=array([1]))

# %%
mode(df['age']).mode[0]
# Out:
# 24

# %%
df.apply(lambda x:x)
# Out:
#      name  age  TestScore_1  TestScore_2
# 0   Kunal   42            4           25
# 1   Ankit   52           24           94
# 2   Purva   36           31           57
# 3  Pranav   24            2           62
# 4   Sunil   73            3           70

# %%
df.apply(lambda x:x[0])
# Out:
# name           Kunal
# age               42
# TestScore_1        4
# TestScore_2       25
# dtype: object

# %%
df.apply(lambda x:x[0], axis=1)
# Out:
# 0     Kunal
# 1     Ankit
# 2     Purva
# 3    Pranav
# 4     Sunil
# dtype: object

# %%
df.apply(lambda x:x['age'], axis=1)
# Out:
# 0    42
# 1    52
# 2    36
# 3    24
# 4    73
# dtype: int64
